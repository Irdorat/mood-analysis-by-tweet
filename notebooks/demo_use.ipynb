# %%
import marimo as mo

# %% [markdown]
# #Демо использование обученной модели на данных пользователя
# Показать работу модели на примере пользовательского твита. Модель принимает твит пользователя, а также текущую дату.

# %%
import pickle
from datetime import datetime
import numpy as np
import pandas as pd

# %%
with open('models/catboost.pkl', 'rb') as f:
    model = pickle.load(f)

model = model['catboost_model']  # или другой ключ, под которым сохранена модель

now = datetime.now()

day=now.strftime('%a')
hour=now.hour
def get_time(hour):
    if 6<=hour<11:
        return "morning"
    elif 11<=hour<16:
        return "day"
    elif 16<=21:
        return "evening"
    else:
        return "night"
time=get_time(hour)
text=input('Пользовательский твит: ')
text_len = len(text)
word_count = len(text.split())
words = text.split()
if words:
    unique_word_ratio = len(set(words)) / (len(words) + 1)
else:
    unique_word_ratio = 0

user_df=pd.DataFrame({
    'text': [text],
    'day': [day],
    'time': [time],
    'text_len': [text_len],
    'word_count': [word_count], 
    'unique_word_ratio': [unique_word_ratio]
})
y_user = model.predict(user_df)[0]
print(f'Прогноз эмоциональности твита: {"Негативный" if y_user==0 else "Положительный"}')
# Out:
# Traceback (most recent call last):
#   File "C:\Users\klyko\AppData\Local\Programs\Python\Python310\lib\site-packages\marimo\_runtime\executor.py", line 138, in execute_cell
#     exec(cell.body, glbls)
#   File "", line 1, in <module>
#     with open('models/catboost.pkl', 'rb') as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'models/catboost.pkl'
